# %% [markdown]
# ## Preview
# - [Good supplement github](https://github.com/chizkidd/Karpathy-Neural-Networks-Zero-to-Hero/blob/main/007_GPT/gpt.ipynb)
#
# ## Project itself
# - Only decoder part of transformer
# - Only fine tuning part of GPT
